# %%
import requests
import pandas as pd
from tqdm import tqdm

# ---------------------------------------------
# CONFIGURACIÓN
# ---------------------------------------------
BASE_URL = "https://www.datos.gov.co/resource/jbjy-vk9h.json"
LIMIT = 10000
ANIOS = list(range(2015, 2026))  # de 2015 a 2025

CAMPOS = [
    "nombre_entidad", "nit_entidad", "departamento", "ciudad",
    "tipo_de_contrato", "modalidad_de_contratacion", "fecha_de_firma",
    "fecha_de_inicio_del_contrato", "fecha_de_fin_del_contrato",
    "valor_del_contrato", "proveedor_adjudicado", "documento_proveedor",
    "descripcion_del_proceso", "objeto_del_contrato", "urlproceso",
]

df_total = pd.DataFrame()

# ---------------------------------------------
# DESCARGA POR AÑO
# ---------------------------------------------
for year in ANIOS:
    print(f"\n📅 Descargando contratos de INTERVENTORÍA del año {year}...")
    offset = 0
    lote = 0
    year_data = []

    # Filtro de año usando rango de fechas
    start_date = f"{year}-01-01T00:00:00"
    end_date = f"{year}-12-31T23:59:59"
    where_clause = (
        f"tipo_de_contrato like '%Interventor%' "
        f"AND fecha_de_firma between '{start_date}' and '{end_date}'"
    )

    with tqdm(total=None, desc=f"Año {year}", unit="lote") as pbar:
        while True:
            params = {
                "$select": ",".join(CAMPOS),
                "$where": where_clause,
                "$limit": LIMIT,
                "$offset": offset
            }

            response = requests.get(BASE_URL, params=params)

            if response.status_code != 200:
                print(f"⚠️ Error {response.status_code} en el lote {lote} del año {year}")
                break

            batch = response.json()
            if not batch:
                print(f"✅ Año {year} completado ({lote} lotes descargados)")
                break

            df_batch = pd.DataFrame(batch)
            year_data.append(df_batch)

            offset += LIMIT
            lote += 1
            pbar.update(1)
            pbar.set_postfix({"Registros": len(df_batch), "Offset": offset})

    if year_data:
        df_year = pd.concat(year_data, ignore_index=True)
        df_year["año"] = year
        df_total = pd.concat([df_total, df_year], ignore_index=True)
        print(f"📊 Total {len(df_year):,} registros del año {year}")

print("\n✅ Descarga completa")
print(f"📈 Total general: {len(df_total):,} contratos de interventoría")

# %%
import requests
import pandas as pd
from tqdm import tqdm

# ---------------------------------------------
# CONFIGURACIÓN FUENTE 2
# ---------------------------------------------
BASE_URL_F2 = "https://www.datos.gov.co/resource/f789-7hwg.json"
LIMIT_F2 = 10000
ANIOS_F2 = list(range(2015, 2026))

CAMPOS_F2 = [
    "nombre_entidad","nit_de_la_entidad","departamento_entidad","municipio_entidad",
    "tipo_de_contrato","modalidad_de_contratacion","fecha_de_firma_del_contrato",
    "fecha_ini_ejec_contrato","fecha_fin_ejec_contrato","cuantia_contrato",
    "nom_razon_social_contratista","identificacion_del_contratista",
    "objeto_del_contrato_a_la","detalle_del_objeto_a_contratar","ruta_proceso_en_secop_i",
]

df_secop2 = pd.DataFrame()

# ---------------------------------------------
# DESCARGA POR AÑO FUENTE 2
# ---------------------------------------------
for year in ANIOS_F2:
    print(f"\n📅 [F2] Descargando contratos de INTERVENTORÍA del año {year}...")
    offset = 0
    lote = 0
    year_data = []

    start_date = f"{year}-01-01T00:00:00"
    end_date = f"{year}-12-31T23:59:59"
    where_clause = (
        f"upper(tipo_de_contrato) like '%INTERVENTOR%' "
        f"AND fecha_de_firma_del_contrato between '{start_date}' and '{end_date}'"
    )

    with tqdm(total=None, desc=f"F2 Año {year}", unit="lote") as pbar:
        while True:
            params = {
                "$select": ",".join(CAMPOS_F2),
                "$where": where_clause,
                "$limit": LIMIT_F2,
                "$offset": offset
            }

            response = requests.get(BASE_URL_F2, params=params)

            if response.status_code != 200:
                print(f"⚠️ [F2] Error {response.status_code} en lote {lote} año {year}")
                break

            batch = response.json()
            if not batch:
                print(f"✅ [F2] Año {year} completado ({lote} lotes)")
                break

            df_batch = pd.DataFrame(batch)
            year_data.append(df_batch)

            offset += LIMIT_F2
            lote += 1
            pbar.update(1)
            pbar.set_postfix({"Registros": len(df_batch)})

    if year_data:
        df_year = pd.concat(year_data, ignore_index=True)
        df_year["año"] = year
        df_secop2 = pd.concat([df_secop2, df_year], ignore_index=True)
        print(f"📊 [F2] Total {len(df_year):,} registros del año {year}")

print("\n✅ Descarga completa F2")
print(f"📈 Total general F2: {len(df_secop2):,} contratos")
# Out:
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2015...
# F2 Año 2015: 1lote [00:00,  1.02lote/s, Registros=2]
# ✅ [F2] Año 2015 completado (1 lotes)
# 📊 [F2] Total 2 registros del año 2015
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2016...
# F2 Año 2016: 1lote [00:01,  1.37s/lote, Registros=2]
# ✅ [F2] Año 2016 completado (1 lotes)
# 📊 [F2] Total 2 registros del año 2016
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2017...
# F2 Año 2017: 1lote [00:03,  3.43s/lote, Registros=87]
# ✅ [F2] Año 2017 completado (1 lotes)
# 📊 [F2] Total 87 registros del año 2017
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2018...
# F2 Año 2018: 1lote [00:09,  9.77s/lote, Registros=4187]
# ✅ [F2] Año 2018 completado (1 lotes)
# 📊 [F2] Total 4,187 registros del año 2018
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2019...
# F2 Año 2019: 1lote [00:08,  8.38s/lote, Registros=6223]
# ✅ [F2] Año 2019 completado (1 lotes)
# 📊 [F2] Total 6,223 registros del año 2019
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2020...
# F2 Año 2020: 1lote [00:06,  6.53s/lote, Registros=1794]
# ✅ [F2] Año 2020 completado (1 lotes)
# 📊 [F2] Total 1,794 registros del año 2020
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2021...
# F2 Año 2021: 1lote [00:05,  5.92s/lote, Registros=3375]
# ✅ [F2] Año 2021 completado (1 lotes)
# 📊 [F2] Total 3,375 registros del año 2021
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2022...
# F2 Año 2022: 1lote [00:04,  4.16s/lote, Registros=2825]
# ✅ [F2] Año 2022 completado (1 lotes)
# 📊 [F2] Total 2,825 registros del año 2022
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2023...
# F2 Año 2023: 1lote [00:02,  2.46s/lote, Registros=3424]
# ✅ [F2] Año 2023 completado (1 lotes)
# 📊 [F2] Total 3,424 registros del año 2023
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2024...
# F2 Año 2024: 1lote [00:02,  2.32s/lote, Registros=917]
# ✅ [F2] Año 2024 completado (1 lotes)
# 📊 [F2] Total 917 registros del año 2024
#
# 📅 [F2] Descargando contratos de INTERVENTORÍA del año 2025...
# F2 Año 2025: 1lote [00:02,  2.04s/lote, Registros=931]
# ✅ [F2] Año 2025 completado (1 lotes)
# 📊 [F2] Total 931 registros del año 2025
#
# ✅ Descarga completa F2
# 📈 Total general F2: 23,767 contratos

# %%
df_total.isnull().sum()
# Out:
# nombre_entidad                    0
# nit_entidad                       0
# departamento                      0
# ciudad                            0
# tipo_de_contrato                  0
# modalidad_de_contratacion         0
# fecha_de_firma                    0
# fecha_de_inicio_del_contrato    312
# fecha_de_fin_del_contrato         0
# valor_del_contrato                0
# proveedor_adjudicado              0
# documento_proveedor               0
# descripcion_del_proceso           0
# objeto_del_contrato               0
# urlproceso                        0
# año                               0
# dtype: int64

# %%
df_secop2.isnull().sum()
# Out:
# nombre_entidad                    0
# nit_de_la_entidad                 0
# departamento_entidad              0
# municipio_entidad                 0
# tipo_de_contrato                  0
# modalidad_de_contratacion         0
# fecha_de_firma_del_contrato       0
# fecha_ini_ejec_contrato           0
# fecha_fin_ejec_contrato           0
# cuantia_contrato                  0
# nom_razon_social_contratista      0
# identificacion_del_contratista    0
# objeto_del_contrato_a_la          0
# detalle_del_objeto_a_contratar    0
# ruta_proceso_en_secop_i           0
# año                               0
# dtype: int64

# %%
# 1. Strip en columnas string
for col in df_total.select_dtypes(include='object').columns:
    df_total[col] = df_total[col].astype(str).str.strip()

# 2. Convertir fechas a datetime
df_total['fecha_de_firma'] = pd.to_datetime(df_total['fecha_de_firma'], errors='coerce')
df_total['fecha_de_inicio_del_contrato'] = pd.to_datetime(df_total['fecha_de_inicio_del_contrato'], errors='coerce')
df_total['fecha_de_fin_del_contrato'] = pd.to_datetime(df_total['fecha_de_fin_del_contrato'], errors='coerce')

# 3. Reemplazar nulos de fecha_inicio por fecha_firma
df_total['fecha_de_inicio_del_contrato'] = df_total['fecha_de_inicio_del_contrato'].fillna(df_total['fecha_de_firma'])

# 4. Convertir valor a numérico
df_total['valor_del_contrato'] = (
    df_total['valor_del_contrato']
    .astype(str)
    .str.replace(r'[^\d.,]', '', regex=True)
    .str.replace(',', '')
    .astype(float)
)

# 5. Año a int
df_total['año'] = df_total['año'].astype(int)

# 6. Renombrar columnas para merge
df_total = df_total.rename(columns={
    'nit_entidad': 'nit',
    'departamento': 'departamento',
    'ciudad': 'municipio',
    'fecha_de_inicio_del_contrato': 'fecha_inicio',
    'fecha_de_fin_del_contrato': 'fecha_fin',
    'fecha_de_firma': 'fecha_firma',
    'valor_del_contrato': 'cuantia',
    'proveedor_adjudicado': 'contratista',
    'documento_proveedor': 'identificacion_contratista',
    'objeto_del_contrato': 'objeto',
    'descripcion_del_proceso': 'detalle_objeto',
    'urlproceso': 'url_proceso'
})

# %%
# 1. Strip texto
for col in df_secop2.select_dtypes(include='object').columns:
    df_secop2[col] = df_secop2[col].astype(str).str.strip()

# 2. Convertir fechas
df_secop2['fecha_de_firma_del_contrato'] = pd.to_datetime(df_secop2['fecha_de_firma_del_contrato'], errors='coerce')
df_secop2['fecha_ini_ejec_contrato'] = pd.to_datetime(df_secop2['fecha_ini_ejec_contrato'], errors='coerce')
df_secop2['fecha_fin_ejec_contrato'] = pd.to_datetime(df_secop2['fecha_fin_ejec_contrato'], errors='coerce')

# 3. Convertir cuantía
df_secop2['cuantia_contrato'] = (
    df_secop2['cuantia_contrato']
    .astype(str)
    .str.replace(r'[^\d.,]', '', regex=True)
    .str.replace(',', '')
    .astype(float)
)

# 4. Año como int
df_secop2['año'] = df_secop2['año'].astype(int)

# 5. Renombrar columnas a estándar del DF1
df_secop2 = df_secop2.rename(columns={
    'nit_de_la_entidad': 'nit',
    'departamento_entidad': 'departamento',
    'municipio_entidad': 'municipio',
    'fecha_de_firma_del_contrato': 'fecha_firma',
    'fecha_ini_ejec_contrato': 'fecha_inicio',
    'fecha_fin_ejec_contrato': 'fecha_fin',
    'cuantia_contrato': 'cuantia',
    'nom_razon_social_contratista': 'contratista',
    'identificacion_del_contratista': 'identificacion_contratista',
    'objeto_del_contrato_a_la': 'objeto',
    'detalle_del_objeto_a_contratar': 'detalle_objeto',
    'ruta_proceso_en_secop_i': 'url_proceso'
})

# %%
df_unido = pd.concat([df_total, df_secop2], ignore_index=True)

# %%
df_unido
# Out:
#                                           nombre_entidad          nit  \
# 0                 MINISTERIO DE EDUCACION NACIONAL (MEN)    899999001
# 1                                        FONDO ROTATORIO   8605110716
# 2                         FUERZA AEROESPACIAL COLOMBIANA    899999102
# 3                         FUERZA AEROESPACIAL COLOMBIANA    899999102
# 4      FONDO DE VIGILANCIA Y SEGURIDAD DE BOGOTÁ D.C ...    860526499
# ...                                                  ...          ...
# 35115          NARIÑO - ALCALDiA MUNICIPIO DE YACUANQUER    800099153
# 35116              NARIÑO - ALCALDiA MUNICIPIO DE TANGUA    800099151
# 35117  NORTE DE SANTANDER - ALCALDiA MUNICIPIO DE SAN...  890501876-4
# 35118  CAUCA - EMPRESA CAUCANA DE SERVICIOS PuBLICOS ...    900316215
# 35119  CAUCA - EMPRESA CAUCANA DE SERVICIOS PuBLICOS ...    900316215
#
#                      departamento     municipio tipo_de_contrato  \
# 0      Distrito Capital de Bogotá        Bogotá    Interventoría
# 1      Distrito Capital de Bogotá   No Definido    Interventoría
# 2      Distrito Capital de Bogotá        Bogotá    Interventoría
# 3      Distrito Capital de Bogotá        Bogotá    Interventoría
# 4                     No Definido   No Definido    Interventoría
# ...                           ...           ...              ...
# 35115                      NARIÑO    YACUANQUER    INTERVENTORiA
# 35116                      NARIÑO        TANGUA    INTERVENTORiA
# 35117          NORTE DE SANTANDER  SAN CAYETANO    INTERVENTORiA
# 35118                       CAUCA       POPAYaN    INTERVENTORiA
# 35119                       CAUCA       POPAYaN    INTERVENTORiA
#
#          modalidad_de_contratacion fecha_firma fecha_inicio  fecha_fin  \
# 0      Concurso de méritos abierto  2016-06-23   2016-06-20 2016-12-31
# 1      Concurso de méritos abierto  2016-08-04   2016-07-25 2016-12-31
# 2      Concurso de méritos abierto  2016-11-02   2016-11-01 2018-03-31
# 3      Concurso de méritos abierto  2016-11-02   2016-11-01 2018-03-31
# 4      Concurso de méritos abierto  2017-02-10   2017-01-17 2017-10-16
# ...                            ...         ...          ...        ...
# 35115  CONTRATACIoN MiNIMA CUANTiA  2025-10-27   2025-10-27 2025-12-27
# 35116  CONTRATACIoN MiNIMA CUANTiA  2025-10-27   2025-10-27 2026-01-25
# 35117  CONTRATACIoN MiNIMA CUANTiA  2025-10-30   2025-10-30 2025-12-30
# 35118  CONTRATACIoN MiNIMA CUANTiA  2025-10-31   2025-10-31 2026-03-31
# 35119  CONCURSO DE MeRITOS ABIERTO  2025-10-31   2025-10-31 2026-08-31
#
#            cuantia                                        contratista  \
# 0      448499078.0  C & M Asesoría y Consultoría S.A.S- BIC absorb...
# 1       57482000.0                                        PANIVI DIEZ
# 2      526587388.0        MEDINA & RIVERA INGENIEROS ASOCIADOS S.A.S.
# 3      526587388.0        MEDINA & RIVERA INGENIEROS ASOCIADOS S.A.S.
# 4      893297074.0                                   CONSORCIO CANTON
# ...            ...                                                ...
# 35115   17196849.0                         SANDRA DEL PILAR PAZ JOJOA
# 35116   12000000.0                         JENNY JOHANNA TELLEZ SALAS
# 35117   34013000.0        UNION TEMPORAL INTER EDUCATIVA SAN CAYETANO
# 35118   36500870.0                               CONSORCIO AQUA VITAL
# 35119  525900508.0  CONSORCIO INTERVENTORIA ALCANTARILLADO PUERTO ...
#
#       identificacion_contratista  \
# 0                      830061474
# 1                    No Definido
# 2                      830013230
# 3                      830013230
# 4                     9007946104
# ...                          ...
# 35115                 1085282785
# 35116                   59833203
# 35117                  902002797
# 35118                  901998643
# 35119                  902003550
#
#                                           detalle_objeto  \
# 0      “REALIZAR LA INTERVENTORÍA INTEGRAL (ADMINISTR...
# 1      CONTRATAR LA INTERVENTORÍA TÉCNICA; ADMINISTRA...
# 2      INTERVENTORÍA TÉCNICA; ADMINISTRATIVA; FINANCI...
# 3      INTERVENTORÍA TÉCNICA; ADMINISTRATIVA; FINANCI...
# 4      El contratista se obliga con la SCJ a prestar ...
# ...                                                  ...
# 35115  INTERVENTORIA TeCNICA; ADMINISTRATIVA Y FINANC...
# 35116  INTERVENTORiA TeCNICA; Y ADMINISTRATIVA; PARA ...
# 35117  INTERVENTORiA INTEGRAL (ADMINISTRATIVA; FINANC...
# 35118  EL CONTRATISTA SE OBLIGA PARA CON EMCASERVICIO...
# 35119  EL CONTRATISTA SE OBLIGA CON EMCASERVICIOS S.A...
#
#                                                   objeto  \
# 0      “REALIZAR LA INTERVENTORÍA INTEGRAL (ADMINISTR...
# 1      CONTRATAR LA INTERVENTORÍA TÉCNICA; ADMINISTRA...
# 2      INTERVENTORÍA TÉCNICA; ADMINISTRATIVA; FINANCI...
# 3      INTERVENTORÍA TÉCNICA; ADMINISTRATIVA; FINANCI...
# 4      El contratista se obliga con la SCJ a prestar ...
# ...                                                  ...
# 35115  INTERVENTORIA TECNICA; ADMINISTRATIVA Y FINANC...
# 35116  INTERVENTORIA TECNICA; Y ADMINISTRATIVA; PARA ...
# 35117  INTERVENTORIA INTEGRAL (ADMINISTRATIVA; FINANC...
# 35118  EL CONTRATISTA SE OBLIGA PARA CON EMCASERVICIO...
# 35119  EL CONTRATISTA SE OBLIGA CON EMCASERVICIOS S.A...
#
#                                              url_proceso   año
# 0      {'url': 'https://community.secop.gov.co/Public...  2016
# 1      {'url': 'https://community.secop.gov.co/Public...  2016
# 2      {'url': 'https://community.secop.gov.co/Public...  2016
# 3      {'url': 'https://community.secop.gov.co/Public...  2016
# 4      {'url': 'https://community.secop.gov.co/Public...  2017
# ...                                                  ...   ...
# 35115  {'url': 'https://www.contratos.gov.co/consulta...  2025
# 35116  {'url': 'https://www.contratos.gov.co/consulta...  2025
# 35117  {'url': 'https://www.contratos.gov.co/consulta...  2025
# 35118  {'url': 'https://www.contratos.gov.co/consulta...  2025
# 35119  {'url': 'https://www.contratos.gov.co/consulta...  2025
#
# [35120 rows x 16 columns]

# %%
# PARA SABER NOMBRE DE LAS COLUMNAS DE DATOS
import requests
import json

BASE_URL = "https://www.datos.gov.co/resource/f789-7hwg.json"

resp = requests.get(BASE_URL, params={"$limit": 1})
print(json.dumps(resp.json(), indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "uid": "19-4-8885396-8083687",
#     "anno_cargue_secop": "2019",
#     "anno_firma_contrato": "2018",
#     "nivel_entidad": "TERRITORIAL",
#     "orden_entidad": "TERRITORIAL DISTRITAL MUNICIPAL NIVEL 2",
#     "nombre_entidad": "ARAUCA - E.S.E. MORENO Y CLAVIJO - ARAUCA",
#     "nit_de_la_entidad": "900034131",
#     "c_digo_de_la_entidad": "281000038",
#     "id_modalidad": "4",
#     "modalidad_de_contratacion": "ReGIMEN ESPECIAL",
#     "estado_del_proceso": "CELEBRADO",
#     "causal_de_otras_formas_de": "No Definido",
#     "id_regimen_de_contratacion": "4",
#     "nombre_regimen_de_contratacion": "ReGIMEN ESPECIAL",
#     "id_objeto_a_contratar": "80000000",
#     "objeto_a_contratar": "SERVICIOS DE GESTION, SERVICIOS PROFESIONALES DE EMPRESA Y SERVICIOS ADMINISTRATIVOS",
#     "detalle_del_objeto_a_contratar": "AUXILIAR DE ENFERMERIA",
#     "tipo_de_contrato": "PRESTACIoN DE SERVICIOS",
#     "municipio_de_obtencion": "No Definido",
#     "municipio_de_entrega": "No Definido",
#     "municipios_ejecucion": "ARAUCA",
#     "fecha_de_cargue_en_el_secop": "2019-01-18T00:00:00.000",
#     "numero_de_constancia": "19-4-8885396",
#     "numero_de_proceso": "001-4033",
#     "numero_de_contrato": "001-4033",
#     "cuantia_proceso": "1316000",
#     "id_grupo": "F",
#     "nombre_grupo": "[F] SERVICIOS",
#     "id_familia": "8011",
#     "nombre_familia": "SERVICIOS DE RECURSOS HUMANOS",
#     "id_clase": "801116",
#     "nombre_clase": "SERVICIOS DE PERSONAL TEMPORAL",
#     "id_adjudicacion": "8083687",
#     "tipo_identifi_del_contratista": "CeDULA DE CIUDADANiA",
#     "identificacion_del_contratista": "24246718",
#     "nom_razon_social_contratista": "EDILMA MARTINEZ ACEVEDO",
#     "dpto_y_muni_contratista": "ARAUCA",
#     "tipo_doc_representante_legal": "CeDULA DE CIUDADANiA",
#     "identific_representante_legal": "24246718",
#     "nombre_del_represen_legal": "EDILMA MARTINEZ ACEVEDO",
#     "fecha_de_firma_del_contrato": "2018-10-16T00:00:00.000",
#     "fecha_ini_ejec_contrato": "2018-10-16T00:00:00.000",
#     "plazo_de_ejec_del_contrato": "1",
#     "rango_de_ejec_del_contrato": "M",
#     "tiempo_adiciones_en_dias": "0",
#     "tiempo_adiciones_en_meses": "0",
#     "fecha_fin_ejec_contrato": "2018-11-16T00:00:00.000",
#     "compromiso_presupuestal": "No definido",
#     "cuantia_contrato": "1316000",
#     "valor_total_de_adiciones": "0",
#     "valor_contrato_con_adiciones": "1316000",
#     "objeto_del_contrato_a_la": "AUXILIAR DE ENFERMERIA",
#     "proponentes_seleccionados": "No Definido",
#     "calificacion_definitiva": "No Definido",
#     "id_sub_unidad_ejecutora": "0",
#     "nombre_sub_unidad_ejecutora": "No Definido",
#     "ruta_proceso_en_secop_i": {
#       "url": "https://www.contratos.gov.co/consultas/detalleProceso.do?numConstancia=19-4-8885396"
#     },
#     "moneda": "PESO COLOMBIANO",
#     "es_postconflicto": "0",
#     "marcacion_adiciones": "0",
#     "posicion_rubro": "No Definido",
#     "nombre_rubro": "No Definido",
#     "valor_rubro": "0",
#     "sexo_replegal": "No definido",
#     "pilar_acuerdo_paz": "No Definido",
#     "punto_acuerdo_paz": "No Definido",
#     "municipio_entidad": "ARAUCA",
#     "departamento_entidad": "ARAUCA",
#     "ultima_actualizacion": "2019-01-18T00:00:00.000",
#     "cumpledecreto248": "No definido",
#     "incluyebienesdecreto248": "No definido",
#     "cumple_sentencia_t302": "No definido",
#     "es_mipyme": "No definido",
#     "tama_o_mipyme": "No definido",
#     "codigo_bpin": "No definido",
#     "destino_gasto": "No aplica"
#   }
# ]
